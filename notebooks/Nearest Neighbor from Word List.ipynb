# %%
import fasttext
import numpy as np

# cosine similarity of word vectors

from numpy import dot
from numpy.linalg import norm

# cos_sim = dot(a, b)/(norm(a)*norm(b))

# %%
#load fasttext model

model = fasttext.load_model("/Users/alex/result/cc.en.300.bin")

# %%
#create numpy array to store word vectors

#currently set to store 29153 words as their 100 dimensional word vectors

arr = np.ndarray(shape=(29153, 300))

# %%
# Set of words from combined TF-IDF analysis results

f = open("word_list.txt", "r")

doc = f.read()

f.close()

#print(doc)

words = doc.split(", ")

print(words)
# Out:
# ['110th', '11th', '123rd', '125th', '12th', '13th', '158th', '15th', '1890s', '18th', '1_st', '200th', '21st', '23rd', '242nd', '26th', '275th', '27th', '28th', '2l6', '2l8', '2nd', '2о', '31_st', '31st', '33rd', '34th', '3_d', '40th', '42nd', '47th', '50th', '5th', '5о', '60th', '66oo', '7th', '9th', '_i', 'aaaaah', 'aaaah', 'aaah', 'aah', 'aardvark', 'aback', 'abacus', 'abaft', 'abandon', 'abandoned', 'abandonedly', 'abandoning', 'abandonment', 'abandons', 'abased', 'abasement', 'abashed', 'abated', 'abating', 'abbey', 'abbeys', 'abbot', 'abbreviate', 'abbreviations', 'abeam', 'abed', 'abednego', 'abel', 'abelard', 'abetted', 'abhor', 'abhorred', 'abhorrence', 'abhorrent', 'abhorring', 'abide', 'abided', 'abides', 'abiding', 'abilene', 'abilities', 'ability', 'abject', 'abjectly', 'abjectus', 'ablaze', 'able', 'abler', 'ablutions', 'ably', 'abnormal', 'abnormalities', 'abnormality', 'aboard', 'abode', 'aboil', 'abolishing', 'abominable', 'abominate', 'abominated', 'abomination', 'aboriginal', 'aboriginally', 'aboriginalness', 'abortion', 'abortions', 'abortive', 'abound', 'abounded', 'aboundingly', 'abraham', 'abrams', 'abreast', 'abridged', 'abroad', 'abrupt', 'abruptly', 'absence', 'absent', 'absently', 'absentmindedness', 'absentness', 'abso', 'absolute', 'absolutely', 'absolution', 'absorb', 'absorbed', 'absorbedly', 'absorbent', 'absorbing', 'absorbingly', 'absorbs', 'absorption', 'abstain', 'abstained', 'abstemious', 'abstract', 'abstracted', 'abstractedly', 'abstraction', 'abstractions', 'abstruse', 'abstruseness', 'absurd', 'absurdity', 'absurdly', 'abused', 'abusing', 'abysmal', 'abyss', 'abysses', 'abyssinian', 'academic', 'academics', 'academies', 'academy', 'acapulco', 'acceded', 'accelerate', 'accelerated', 'accelerating', 'acceleration', 'accelerator', 'accent', 'accents', 'accentual', 'accentuated', 'accept', 'acceptable', 'acceptably', 'acceptance', 'accepted', 'accepting', 'accepts', 'access', 'accessed', 'accessible', 'acciden', 'accident', 'accidental', 'accidentally', 'accidents', 'accom', 'accommodate', 'accommodated', 'accommodations', 'accompanied', 'accompanies', 'accompaniments', 'accompany', 'accompanying', 'accomplish', 'accomplished', 'accomplishing', 'accomplishment', 'accomplishments', 'accord', 'accordance', 'accorded', 'accordin', 'accordingly', 'accordion', 'accords', 'accosted', 'account', 'accounta', 'accountable', 'accountants', 'accounted', 'accounting', 'accounts', 'accu', 'accumulated', 'accumulating', 'accumulation', 'accumulator', 'accuracy', 'accurately', 'accursed', 'accusations', 'accuse', 'accused', 'accuses', 'accusing', 'accusingly', 'accustomed', 'acerbities', 'acerbity', 'ache', 'ached', 'aches', 'achieve', 'achieved', 'achievement', 'achievements', 'achieving', 'achilles', 'aching', 'acidly', 'ack', 'acknowledge', 'acknowledged', 'acknowledges', 'acknowledging', 'acme', 'acolytes', 'acorns', 'acoustical', 'acquaintance', 'acquaintances', 'acquainted', 'acquainting', 'acquiesce', 'acquiesced', 'acquiescing', 'acquire', 'acquired', 'acquirement', 'acquires', 'acquiring', 'acquisition', 'acquit', 'acquittal', 'acquitted', 'acre', 'acres', 'acridness', 'acrobat', 'acrobatic', 'acrobats', 'acrosis', 'across', 'acted', 'actest', 'acting', 'actium', 'activa', 'activating', 'active', 'actively', 'activities', 'activity', 'actor', 'actors', 'actress', 'actu', 'actual', 'actually', 'actuated', 'acuity', 'acushnet', 'acute', 'acutely', 'acuteness', 'ada', 'adam', 'adamite', 'adaptations', 'adapting', 'adapts', 'add', 'added', 'addenda', 'addict', 'addicts', 'adding', 'addition', 'additional', 'additions', 'address', 'addressed', 'addresses', 'addressing', 'adduced', 'adel', 'adeline', 'adeo', 'adept', 'adepts', 'adequate', 'adequately', 'adherents', 'adhering', 'adhesive', 'adhesiveness', 'adieu', 'adieux', 'adios', 'adirondack', 'adirondacks', 'adjourned', 'adjuncts', 'adjuration', 'adjusted', 'adjusting', 'adjustment', 'adjustments', 'admeasurement', 'admeasurements', 'administered',  ...

# %%
print(len(words))
# Out:
# 29153

# %%
# Store word vectors for the 29153 words in numpy array

for i in range(0, 29153):
    arr[i] = model.get_word_vector(words[i])

# %%
# user word
user_word = "boring"

user_word_vec = model.get_word_vector(user_word)

results = {}

# iterate through numpy array and find vectors that meet a threshold for cosine similarity
cos_sim = 0.6
for i in range(0, 29153):
    current = dot(user_word_vec, arr[i]) / (norm(user_word_vec) * norm(arr[i]))
    if current > cos_sim and words[i] != user_word and user_word[0:2] != words[i][0:2] and user_word[0:3] not in words[i]:
        results[words[i]] = current
# Out:
# <ipython-input-11-d4a8e661c07e>:11: RuntimeWarning: invalid value encountered in double_scalars
#   current = dot(user_word_vec, arr[i]) / (norm(user_word_vec) * norm(arr[i]))

# %%
print(model.get_nearest_neighbors(user_word)[0:5])
# Out:
# [(0.7616065740585327, 'monotonous'), (0.7564576268196106, 'uninteresting'), (0.7449483275413513, 'BORING'), (0.7424657940864563, 'dull'), (0.7396818399429321, 'booooring')]

# %%
print(results)
# Out:
# {'banal': 0.6094856527081209, 'bland': 0.6907541430220538, 'monotonous': 0.7616066676895861, 'pointless': 0.6145473633902698, 'tedious': 0.6804934319914236, 'tiresome': 0.6523776282595005, 'unimaginative': 0.6317385391423974, 'uninteresting': 0.7564575979497881}

# %%
import timeit

start = timeit.default_timer()

# user word
user_word = "exit"

user_word_vec = model.get_word_vector(user_word)

results = {}

# iterate through numpy array and find vectors that meet a threshold for cosine similarity
cos_sim = 0.5
for i in range(0, 29153):
    current = dot(user_word_vec, arr[i]) / (norm(user_word_vec) * norm(arr[i]))
    if current > cos_sim and words[i] != user_word and user_word[0:2] != words[i][0:2] and user_word[0:3] not in words[i]:
        results[words[i]] = current
        
stop = timeit.default_timer()

print('Time: ', stop - start)
# Out:
# <ipython-input-50-352b944bf1b1>:15: RuntimeWarning: invalid value encountered in double_scalars
#   current = dot(user_word_vec, arr[i]) / (norm(user_word_vec) * norm(arr[i]))
# Time:  0.5698443979999865

# %%
import timeit

start = timeit.default_timer()

print(model.get_nearest_neighbors(user_word)[0:10])

        
stop = timeit.default_timer()

print('Time: ', stop - start)
# Out:
# [(0.7515513300895691, 'exits'), (0.710208535194397, 'Exit'), (0.6907676458358765, 'exiting'), (0.6859351396560669, 'exit.The'), (0.6736966967582703, 'exit.'), (0.606399655342102, 'exit-'), (0.5831857323646545, 'exit.I'), (0.5821238160133362, 'post-exit'), (0.5819605588912964, 'entrance'), (0.5802634954452515, 'Exiting')]
# Time:  0.8265621760001522

# %%
print(results)
# Out:
# {'enter': 0.5088557991739595}

# %%
import timeit

start = timeit.default_timer()

# user word
user_words = ["green", "strive", "confuse", "confused", "chaotic", "patriotic"]

for user_word in user_words:
    user_word_vec = model.get_word_vector(user_word)

    results = {}

    # iterate through numpy array and find vectors that meet a threshold for cosine similarity
    cos_sim = 0.5
    for i in range(0, 29153):
        current = dot(user_word_vec, arr[i]) / (norm(user_word_vec) * norm(arr[i]))
        if current > cos_sim and words[i] != user_word and user_word[0:2] != words[i][0:2] and user_word[0:3] not in words[i]:
            results[words[i]] = current
    print("----------")
    print(user_word)
    print(results)
    print("----------")
    print(model.get_nearest_neighbors(user_word)[0:10])
        
stop = timeit.default_timer()

print('Time: ', stop - start)
# Out:
# <ipython-input-53-5e66d94ad987>:16: RuntimeWarning: invalid value encountered in double_scalars
#   current = dot(user_word_vec, arr[i]) / (norm(user_word_vec) * norm(arr[i]))
# ----------
# green
# {'beige': 0.5087639869666484, 'black': 0.5034172134585541, 'blue': 0.7049703508972704, 'brown': 0.5575932985965545, 'burgundy': 0.5111538182011831, 'chartreuse': 0.5471285389737149, 'leafy': 0.5317110569413886, 'orange': 0.6341297882527163, 'pink': 0.577586019286454, 'purple': 0.6663211181996233, 'red': 0.6794081856455708, 'verdant': 0.5253004230971813, 'white': 0.5263655191297404, 'yellow': 0.6820157608839775, 'yellowy': 0.505709682598665}
# ----------
# [(0.7388068437576294, 'greeen'), (0.7049704194068909, 'blue'), (0.6820159554481506, 'yellow'), (0.6794081926345825, 'red'), (0.6742905378341675, 'green-'), (0.6663212180137634, 'purple'), (0.6522365212440491, 'green-ish'), (0.6520159840583801, 'green.The'), (0.6385214328765869, '-green'), (0.6341298818588257, 'orange')]
# ----------
# strive
# {'achieve': 0.5274633111706744, 'aspire': 0.6008176166460104, 'aspires': 0.5069036054674214, 'assure': 0.5160957591800293, 'attain': 0.5102392810342917, 'continually': 0.5076850575922989, 'continue': 0.5058669099981895, 'diligently': 0.5030848337539516, 'encourage': 0.5355996962307089, 'endeavor': 0.5051433077225044, 'endeavored': 0.5026476885934033, 'endeavoring': 0.5205301958984623, 'endeavour': 0.5433897105699422, 'ensure': 0.5136874041976883, 'provide': 0.505556587221599, 'seek': 0.5311747820362336, 'tirelessly': 0.5140039816047666}
# ----------
# [(0.7951453328132629, 'striving'), (0.7725051045417786, 'strives'), (0.7386497259140015, 'strived'), (0.646567702293396, 'striven'), (0.6008174419403076, 'aspire'), (0.5895738005638123, 'Strive'), (0.571056067943573, 'strove'), (0.5677306652069092, 'stive'), (0.5567888021469116, 'Striving'), (0.5433894395828247, 'endeavour')]
# ----------
# confuse
# {'annoy': 0.5761479375990757, 'bother': 0.5434993777081003, 'clarify': 0.5266543388866297, 'discourage': 0.5072420987296723, 'distinguish': 0.5372536887379058, 'distract': 0.5435197124315709, 'enlighten': 0.5570004585724937, 'frighten': 0.5616701691145136, 'hoodwink': 0.507808824975215, 'ignore': 0.5143973326011779, 'intimidate': 0.5240255754293003, 'misjudge': 0.5014807301881402, 'misunderstand': 0.6477879608115474, 'offend': 0.5221442052329585, 'overwhelm': 0.5016844094999399, 'understand': 0.5361471207377446}
# ----------
# {'cluttered': 0.5214166343832299, 'disarray': 0.5255183652247558, 'disorganized': 0.634648694105948, 'frantic': 0.5588447144230982, 'frazzled': 0.5014774446098509, 'frenzied': 0.5487182405564925, 'haphazard': 0.6177120260362203, 'hectic': 0.619436442983628, 'hellish': 0.537202500380293, 'incoherent': 0.5102128229612013, 'jumbled': 0.5169103059539394, 'maddening': 0.501270121409107, 'madhouse': 0.5093120038449427, 'maelstrom': 0.5018281842276114, 'messy': 0.603234309640922, 'nightmarish': 0.5334663570096675, 'orderly': 0.5464329834948032, 'riotous': 0.5233227386235493, 'tumultuous': 0.5860360547424739, 'turbulent': 0.5904461855987375, 'turmoil': 0.5083493946448577, 'unpredictable': 0.6449789487559845, 'unruly': 0.5120267435932522, 'unstable': 0.5527166842737163}
# ----------
# [(0.7356657385826111, 'chaos'), (0.729794979095459, 'choatic'), (0.6890619993209839, 'chaotically'), (0.6872125864028931, 'non-chaotic'), (0.6449790596961975, 'unpredictable'), (0.6346489191055298, 'disorganized'), (0.6228154301643372, 'anarchic'), (0.619436502456665, 'hectic'), (0.6191022992134094, 'frenetic'), (0.6177122592926025, 'haphazard')]
# ----------
# patriotic
# {'nationalist': 0.5321627559889469}
# ----------
# [(0.7362048029899597, 'patriotism'), (0.7238456010818481, 'patriotically'), (0.6987369656562805, 'non-patriotic'), (0.6833669543266296, 'patriotic-themed'), (0.6647852063179016, 'jingoistic'), (0.6645117998123169, 'nationalistic'), (0.6543452739715576, 'Patriotic'), (0.6389138698577881, 'ultra-patriotic'), (0.6352426409721375, 'flag-waving'), (0.6319202780723572, 'anti-patriotic')]
# Time:  8.394273643000133

# %%
import timeit

start = timeit.default_timer()

# user word
user_words = ["creativity", "flow", "optimistic", "say", "travel", "revere", "angry", "iron"]

for user_word in user_words:
    user_word_vec = model.get_word_vector(user_word)

    results = {}

    # iterate through numpy array and find vectors that meet a threshold for cosine similarity
    cos_sim = 0.5
    for i in range(0, 29153):
        current = dot(user_word_vec, arr[i]) / (norm(user_word_vec) * norm(arr[i]))
        if current > cos_sim and words[i] != user_word and user_word[0:2] != words[i][0:2] and user_word[0:3] not in words[i]:
            results[words[i]] = current
    print("----------")
    print(user_word)
    print(results)
    print("----------")
    print(model.get_nearest_neighbors(user_word)[0:10])
        
stop = timeit.default_timer()

print('Time: ', stop - start)
# Out:
# <ipython-input-54-ee955598bc41>:16: RuntimeWarning: invalid value encountered in double_scalars
#   current = dot(user_word_vec, arr[i]) / (norm(user_word_vec) * norm(arr[i]))
# ----------
# creativity
# {'artistic': 0.572791794593144, 'artistry': 0.6092128658077277, 'brilliance': 0.5379789827741969, 'dynamism': 0.5574889745690873, 'enthusiasm': 0.5330109688123644, 'exuberance': 0.5191516422175286, 'fearlessness': 0.5316144667067941, 'imagination': 0.672217714430472, 'imaginations': 0.509270193163366, 'imaginative': 0.5167465765229431, 'individuality': 0.5627556400052934, 'ingenuity': 0.6314415855224427, 'innovation': 0.5921892625625782, 'inquisitiveness': 0.5327277770990606, 'inventiveness': 0.7082116202687242, 'openness': 0.5035090789536434, 'passion': 0.5398007942558316, 'playfulness': 0.578397036530275, 'resourcefulness': 0.6238586367438534, 'talent': 0.5221888972643199, 'thoughtfulness': 0.5162198908246911, 'virtuosity': 0.5039445845836261}
# ----------
# [(0.7948461174964905, 'creativitiy'), (0.7902669906616211, 'creativeness'), (0.7312301993370056, 'creativty'), (0.7212439775466919, 'creative'), (0.713066577911377, 'Creativity'), (0.7082112431526184, 'inventiveness'), (0.704899251461029, 'creativity-'), (0.6890859603881836, 'creativity.I'), (0.6879140734672546, 'creativity.The'), (0.672217607498169, 'imagination')]
# ----------
# flow
# {}
# ----------
715211610293, 'insulting': 0.5066532510995106, 'irrationally': 0.5245168739550394, 'irritable': 0.6182349966319989, 'irritated': 0.6711009776771976, 'jealous': 0.5754868739536846, 'livid': 0.675210594766847, 'lividly': 0.5318496778596677, 'mad': 0.6099831062204953, 'maddened': 0.5416939413112097, 'miffed': 0.5937404318616607, 'mistrustful': 0.5409998474526532, 'nonplussed': 0.5128055755106294, 'obnoxious': 0.5079354206655339, 'offended': 0.5844484026944577, 'ornery': 0.5310374323041996, 'outburst': 0.5098931547677823, 'outraged': 0.6775461722170983, 'pained': 0.5517786604787528, 'panicky': 0.5651365555202055, 'perplexed': 0.5548749217086734, 'perturbed': 0.5346401388912191, 'provoked': 0.5400368947510278, 'puzzled': 0.5034683259508357, 'rage': 0.5304185306186553, 'resentful': 0.6953926228408187, 'revengeful': 0.5422340953851813, 'rude': 0.5127617716855795, 'sad': 0.5138221011577628, 'saddened': 0.5044188356677775, 'scared': 0.5784623835578858, 'scolded': 0.528672074077072, 'scolding': 0.5020769438399664, 'scornful': 0.5161893433336101, 'seething': 0.5362726130086187, 'seethingly': 0.5936344454086185, 'shocked': 0.5388435686419428, 'spiteful': 0.6131036529752744, 'stupid': 0.5224180421890197, 'sulky': 0.5036194781488292, 'sullen': 0.5688135891024733, 'taunting': 0.5076535919947796, 'tearful': 0.523665258699854, 'terrified': 0.550758895407338, 'tired': 0.5157211170590783, 'ungrateful': 0.5448680752104632, 'unhappy': 0.6680253952358748, 'unkind': 0.5174649953714986, 'unnerved': 0.5595546519239812, 'unsympathetic': 0.507324356985833, 'upset': 0.6970031008016279, 'vengeful': 0.5819342636193745, 'vindictive': 0.5837197052981836, 'whiny': 0.5333647593141811, 'worried': 0.5368778127822386, 'wrathful': 0.5770923587036988}
# ----------
# [(0.8004297018051147, 'enraged'), (0.7334062457084656, 'angrier'), (0.7321648001670837, 'indignant'), (0.7173984050750732, 'annoyed'), (0.7162356972694397, 'irate'), (0.7107214331626892, 'angered'), (0.7080233693122864, 'infuriated'), (0.7007207274436951, 'frustrated'), (0.6999937891960144, 'angy'), (0.6970033645629883, 'upset')]
# ----------
# iron
# {'aluminium': 0.5046285524502898, 'aluminum': 0.5207627476614665, 'steel': 0.5903255939480617}
# ----------
# [(0.718567967414856, 'iron-'), (0.7109730839729309, 'iron.I'), (0.6899447441101074, 'iron.The'), (0.6890094876289368, 'iron.'), (0.659254252910614, '-iron'), (0.6465622186660767, 'iorn'), (0.6064212322235107, 'zinc'), (0.6058926582336426, 'manganese'), (0.6055341362953186, 'Iron'), (0.5993867516517639, 'irons')]
# Time:  11.707628376000002

# %%
dict(sorted(results.items(), key=lambda item: item[1], reverse=True))
# Out:
# {'steel': 0.5903255939480617,
#  'aluminum': 0.5207627476614665,
#  'aluminium': 0.5046285524502898}

# %%
import timeit

start = timeit.default_timer()

# user word
user_words = ["creativity", "flow", "optimistic", "say", "travel", "revere", "angry", "iron"]

for user_word in user_words:
    user_word_vec = model.get_word_vector(user_word)

    results = {}

    # iterate through numpy array and find vectors that meet a threshold for cosine similarity
    cos_sim = 0.5
    for i in range(0, 29153):
        current = dot(user_word_vec, arr[i]) / (norm(user_word_vec) * norm(arr[i]))
        if current > cos_sim and words[i] != user_word and user_word[0:2] != words[i][0:2] and user_word[0:3] not in words[i]:
            results[words[i]] = current
    print("----------")
    print(user_word.upper())
    results = dict(sorted(results.items(), key=lambda item: item[1], reverse=True))
    print(results.keys())
    print("----------")
    print(model.get_nearest_neighbors(user_word)[0:10])
        
stop = timeit.default_timer()

print('Time: ', stop - start)
# Out:
# <ipython-input-68-eea49c018fd2>:18: RuntimeWarning: invalid value encountered in double_scalars
#   current = dot(user_word_vec, arr[i]) / (norm(user_word_vec) * norm(arr[i]))
# ----------
# CREATIVITY
# dict_keys(['inventiveness', 'imagination', 'ingenuity', 'resourcefulness', 'artistry', 'innovation', 'playfulness', 'artistic', 'individuality', 'dynamism', 'passion', 'brilliance', 'enthusiasm', 'inquisitiveness', 'fearlessness', 'talent', 'exuberance', 'imaginative', 'thoughtfulness', 'imaginations', 'virtuosity', 'openness'])
# ----------
# [(0.7948461174964905, 'creativitiy'), (0.7902669906616211, 'creativeness'), (0.7312301993370056, 'creativty'), (0.7212439775466919, 'creative'), (0.713066577911377, 'Creativity'), (0.7082112431526184, 'inventiveness'), (0.704899251461029, 'creativity-'), (0.6890859603881836, 'creativity.I'), (0.6879140734672546, 'creativity.The'), (0.672217607498169, 'imagination')]
# ----------
# FLOW
# dict_keys([])
# ----------
# [(0.784903883934021, 'flows'), (0.7350473403930664, 'flowing'), (0.7023146152496338, 'flow.The'), (0.6826456785202026, 'flow.This'), (0.6795527935028076, 'ﬂow'), (0.6706947684288025, 'flow.It'), (0.6599457263946533, 'flow.'), (0.6562477946281433, 'flow.If'), (0.6513304114341736, 'flow.I'), (0.6510971784591675, 'flow.In')]
# ----------
# OPTIMISTIC
# dict_keys(['pessimistic', 'hopeful', 'pessimist', 'confident', 'cautious', 'pessimism', 'cynical', 'guardedly', 'skeptical', 'outlook', 'idealistic', 'sceptical', 'enthusiastic', 'cheerful', 'despondent', 'bleak', 'gloomy', 'hopefulness', 'downbeat', 'anxious', 'ambitious', 'realistic', 'cheery', 'noncommittal', 'naive'])
# ----------
# [(0.8438307642936707, 'pessimistic'), (0.7795455455780029, 'optomistic'), (0.7666578888893127, 'hopeful'), (0.7353354096412659, 'optimisitic'), (0.7323648929595947, 'optimistically'), (0.7076685428619385, 'optimistic.The'), (0.6892461180686951, 'optimist'), (0.6878935098648071, 'optimism'), (0.6871453523635864, 'Optimistic'), (0.6869727969169617, 'upbeat')]
# ----------
# SAY
# dict_keys(['know', 'think', 'believe', 'tell', 'argue', 'guess', 'suppose', 'presume', 'honestly', 'mean', 'want', 'yes', 'admit', 'dare', 'expect', 'hey', 'ask', 'truthfully', 'assume', 'hear', 'concede', 'understand', 'misunderstand', 'imagine', 'insist', 'let', 'gotta', 'agree', 'thought', 'would', 'complain', 'yeah', 'surmise', 'swear', 'like', 'suggest', 'remember', 'speculate', 'actually', 'forget', 'wonder', 'realize', 'reckon', 'wish', 'liken', 'thing', 'pretend', 'opine', 'frankly', 'explain', 'dunno', 'confess', 'really'])
# ----------
# [(0.7342773079872131, 'know'), (0.7219211459159851, 'think'), (0.6857853531837463, 'believe'), (0.675372302532196, 'tell'), (0.6636780500411987, 'say.And'), (0.653815746307373, 'saying'), (0.6536467671394348, 'argue'), (0.651170015335083, 'guess'), (0.6450592279434204, 'suppose'), (0.6436644792556763, 'presume')]
# ----------
# TRAVEL
# dict_keys(['destinations', 'journeys', 'destination'])
# ----------
# [(0.7237604260444641, 'traveling'), (0.7064136862754822, 'travelling'), (0.6528444290161133, 'tavel'), (0.6411227583885193, 'Travel'), (0.6378313302993774, 'travels'), (0.6306242346763611, 'trave'), (0.6154276728630066, 'travel.'), (0.6123158931732178, 'travel.I'), (0.6029360294342041, 'travel.If'), (0.5902622938156128, 'travel.The')]
# ----------
# REVERE
# dict_keys(['venerate', 'patriots', 'despise'])
# ----------
# [(0.6940615177154541, 'venerate'), (0.6111630797386169, 'idolize'), (0.5987546443939209, 'lionize'), (0.5964785814285278, 'reveres'), (0.595510721206665, 'adulate'), (0.5782967209815979, 'reverence'), (0.5770868062973022, 'revering'), (0.5559414625167847, 'patriots'), (0.5502600073814392, 'revered'), (0.5473352670669556, 'deify')]
# ----------
# ANGRY
# dict_keys(['enraged', 'indignant', 'infuriated', 'frustrated', 'upset', 'resentful', 'furious', 'outraged', 'incensed', 'livid', 'irritated', 'agitated', 'unhappy', 'exasperated', 'distraught', 'frightened', 'disgusted', 'fuming', 'embittered', 'irritable', 'spiteful', 'despondent', 'insulted', 'mad', 'displeased', 'bewildered', 'miffed', 'seethingly', 'fearful', 'impatient', 'offended', 'vindictive', 'vengeful', 'affronted', 'scared', 'wrathful', 'jealous', 'dejected', 'sullen', 'hateful', 'panicky', 'confused', 'aggrieved', 'heartbroken', 'dismayed', 'unnerved', 'defiant', 'perplexed', 'embarrassed', 'pained', 'terrified', 'incredulous', 'appalled', 'discontented', 'dispirited', 'ungrateful', 'distrustful', 'revengeful', 'maddened', 'arrogant', 'mistrustful', 'provoked', 'disturbed', 'shocked', 'worried', 'seething', 'perturbed', 'depressed', 'whiny', 'lividly', 'disillusioned', 'ornery', 'rage', 'scolded', 'contemptuous', 'alienated', 'irrationally', 'tearful', 'stupid', 'hostile', 'alarmed', 'dissatisfied', 'disrespectful', 'unkind', 'scornful', 'tired', 'horrified', 'sad', 'humiliated', 'amused', 'nonplussed', 'rude', 'harassed', 'bemused', 'outburst', 'crying', 'fury', 'obnoxious', 'taunting', 'unsympathetic', 'insulting', 'befuddled', 'saddened', 'disenchanted', 'complaining', 'sulky', 'puzzled', 'confronted', 'scolding', 'dumbfounded', 'crestfallen'])
# ----------
# [(0.8004297018051147, 'enraged'), (0.7334062457084656, 'angrier'), (0.7321648001670837, 'indignant'), (0.7173984050750732, 'annoyed'), (0.7162356972694397, 'irate'), (0.7107214331626892, 'angered'), (0.7080233693122864, 'infuriated'), (0.7007207274436951, 'frustrated'), (0.6999937891960144, 'angy'), (0.6970033645629883, 'upset')]
# ----------
# IRON
# dict_keys(['steel', 'aluminum', 'aluminium'])
# ----------
# [(0.718567967414856, 'iron-'), (0.7109730839729309, 'iron.I'), (0.6899447441101074, 'iron.The'), (0.6890094876289368, 'iron.'), (0.659254252910614, '-iron'), (0.6465622186660767, 'iorn'), (0.6064212322235107, 'zinc'), (0.6058926582336426, 'manganese'), (0.6055341362953186, 'Iron'), (0.5993867516517639, 'irons')]
# Time:  11.465227859000152

# %%
# Verbs

import timeit

start = timeit.default_timer()

# user word
user_words = ["hit", "exclaim", "buy", "defend", "earn", "gain", "hide", "underestimate", "respect", "support", "rely"]

for user_word in user_words:
    user_word_vec = model.get_word_vector(user_word)

    results = {}

    # iterate through numpy array and find vectors that meet a threshold for cosine similarity
    cos_sim = 0.51
    for i in range(0, 29153):
        current = dot(user_word_vec, arr[i]) / (norm(user_word_vec) * norm(arr[i]))
        if current > cos_sim and words[i] != user_word and user_word[0:2] != words[i][0:2] and user_word[0:3] not in words[i]:
            results[words[i]] = current
    print("----------")
    print(user_word.upper())
    results = dict(sorted(results.items(), key=lambda item: item[1], reverse=True))
    print(results.keys())
    print("----------")
    print(model.get_nearest_neighbors(user_word)[0:10])
        
stop = timeit.default_timer()

print('Time: ', stop - start)
# Out:
# <ipython-input-69-90cd3ceb7e39>:18: RuntimeWarning: invalid value encountered in double_scalars
#   current = dot(user_word_vec, arr[i]) / (norm(user_word_vec) * norm(arr[i]))
# ----------
# HIT
# dict_keys(['smash', 'struck', 'smacked', 'knocked', 'bounced'])
# ----------
# [(0.7565919160842896, 'hitting'), (0.7019004821777344, 'hits'), (0.6800407767295837, 'smash'), (0.6391471028327942, 'Hit'), (0.6280690431594849, 'hit.It'), (0.6275137066841125, 'hit.The'), (0.6097322702407837, 'hitted'), (0.5861843824386597, 'hit.But'), (0.5803191661834717, 'hit.As'), (0.5769892334938049, 'hit.')]
# ----------
# EXCLAIM
# dict_keys(['mutter', 'indignantly', 'yell', 'shouts', 'delightedly', 'shriek', 'groan', 'blurted', 'incredulously', 'shouted', 'gasped', 'disgustedly', 'sarcastically', 'laughingly', 'yells', 'hollered', 'amazement', 'astonishment', 'incredulous', 'shout', 'loudly', 'muttering', 'scream', 'smilingly', 'shrieked', 'wonderingly', 'mockingly', 'groans', 'remarked', 'harrumph', 'breathlessly', 'guffaw', 'sneeringly', 'shrieks', 'mutters', 'gasp', 'scornfully', 'angrily', 'yelled', 'proclaim', 'gasps', 'retorted', 'cheerily', 'chuckling', 'despairingly', 'admiringly', 'triumphantly'])
# ----------
# [(0.8161690831184387, 'exclaiming'), (0.7800217866897583, 'exclaims'), (0.7518976926803589, 'exclaimed'), (0.6548943519592285, 'mutter'), (0.6180355548858643, 'indignantly'), (0.6108910441398621, 'excitedly'), (0.6070343852043152, 'yell'), (0.5897001028060913, 'shouts'), (0.588674783706665, 'delightedly'), (0.5872280597686768, 'shriek')]
# ----------
# BUY
# dict_keys(['sell', 'bought', 'afford', 'selling', 'purchasing', 'invest', 'cheap', 'purchased', 'want', 'borrow', 'cheapest'])
# ----------
# [(0.7792205214500427, 'sell'), (0.7212230563163757, 'buying'), (0.6973830461502075, 'purchase'), (0.6607130169868469, 'bought'), (0.6412587761878967, 'buys'), (0.6371119618415833, 'buy.I'), (0.6261484622955322, 'Buy'), (0.6151348948478699, 'purcahse'), (0.6118899583816528, 'pruchase'), (0.6116228103637695, 'buy.')]
# ----------
# DEFEND
# dict_keys(['protect', 'attacking', 'fortify', 'fight', 'assert', 'rebut', 'refute'])
# ----------
# [(0.7592086791992188, 'defending'), (0.6598309278488159, 'defended'), (0.6531631350517273, 'Defend'), (0.646578311920166, 'protect'), (0.6424742341041565, 'defent'), (0.5917021632194519, 'DEFEND'), (0.589752733707428, 'defends'), (0.572185754776001, 'deffend'), (0.5640426874160767, 'vindicate'), (0.5551601648330688, 'uphold')]
# ----------
# EARN
# dict_keys([])
# ----------
# [(0.8029975891113281, 'earning'), (0.7466927766799927, 'earned'), (0.7383902072906494, 'earns'), (0.7026622891426086, 'Earn'), (0.6086204051971436, 'earnt'), (0.6076681613922119, 'toearn'), (0.5963428616523743, 'Earning'), (0.5808524489402771, 'earn.'), (0.5387399196624756, 'EARN'), (0.5249441266059875, '-Earn')]
# ----------
# GAIN
# dict_keys(['lose', 'attain'])
# ----------
# [(0.7395862340927124, 'gaining'), (0.7152482271194458, 'gained'), (0.6697655320167542, 'gains'), (0.6452895402908325, 're-gain'), (0.631442129611969, 'Gain'), (0.613318920135498, 'lose'), (0.6118626594543457, 'Gaining'), (0.5947412252426147, 'regain'), (0.5779019594192505, 'gain.'), (0.5651417374610901, 'gain.The')]
# ----------
# HIDE
# dict_keys(['conceal', 'disguise', 'concealing', 'conceals', 'disguises'])
# ----------
# [(0.7469778060913086, 'hiding'), (0.7466776371002197, 'conceal'), (0.7188984751701355, 'hides'), (0.685627281665802, 'hid'), (0.645227313041687, 'hide.'), (0.6224328875541687, 'hidding'), (0.607954740524292, 'unhide'), (0.6035758256912231, 'un-hide'), (0.6035321950912476, 'hidden'), (0.6032829880714417, 're-hide')]
# ----------
# UNDERESTIMATE
# dict_keys(['overestimate', 'misjudge', 'exaggerate', 'overlook', 'forget'])
# ----------
# [(0.8832201957702637, 'under-estimate'), (0.8708140850067139, 'overestimate'), (0.8139681816101074, 'over-estimate'), (0.7748346328735352, 'underestimated'), (0.7739045023918152, 'underestimating'), (0.7601242661476135, 'understimate'), (0.7303880453109741, 'under-estimating'), (0.7273223400115967, 'under-estimated'), (0.724738359451294, 'underestimates'), (0.7198713421821594, 'overestimated')]
# ----------
# RESPECT
# dict_keys(['admiration', 'deference', 'dignity', 'disdain'])
# ----------
# [(0.7627286911010742, 'repsect'), (0.7538018822669983, 'repect'), (0.6742987632751465, 'regard'), (0.6244930624961853, 'respects'), (0.623988151550293, 'respect.I'), (0.6233760714530945, 'respect.As'), (0.6221551895141602, 'respect.The'), (0.6193515062332153, 'respecting'), (0.6167236566543579, 'respect.And'), (0.6112678050994873, 'admiration')]
# ----------
# SUPPORT
# dict_keys(['assistance', 'provide', 'help', 'encouragement'])
# ----------
# [(0.7773094177246094, 'suppport'), (0.7178456783294678, 'supporting'), (0.7078533172607422, 'suport'), (0.7020941376686096, 'suppor'), (0.6932756304740906, 'suppot'), (0.6725029349327087, 'supported'), (0.6649244427680969, 'supoort'), (0.6614205837249756, 'supports'), (0.643927812576294, 'support.This'), (0.6390790939331055, 'support.')]
# ----------
# RELY
# dict_keys(['depend', 'depended', 'solely', 'insist'])
# ----------
# [(0.842853844165802, 'relying'), (0.786529541015625, 'relied'), (0.7503169775009155, 'relies'), (0.7246333360671997, 'reliant'), (0.6882734894752502, 'Relying'), (0.677605152130127, 'depend'), (0.6070389747619629, 'reliance'), (0.6048798561096191, 'relys'), (0.5862035155296326, 'depended'), (0.5709444284439087, 'Rely')]
# Time:  15.781048388000272
