# %%
# https://towardsdatascience.com/natural-language-processing-feature-engineering-using-tf-idf-e8b9d00e7e76

import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
from nltk.corpus import stopwords
# stopwords.words('english')

# %%
f = open("invman.txt", "r")

documentA = f.read().split()

f.close()

for i in range(0, len(documentA)):
    documentA[i] = documentA[i].strip(".,!?;:\'\"")

print(documentA[0:100])

documentA = " ".join(documentA)

print(documentA[0:1000])
# Out:
# ['Invisible', 'Man', 'You', 'are', 'saved', 'cried', 'Captain', 'Delano', 'more', 'and', 'more', 'astonished', 'and', 'pained', 'you', 'are', 'saved', 'what', 'has', 'cast', 'such', 'a', 'shadow', 'upon', 'you', 'HARRY', 'I', 'tell', 'you', 'it', 'is', 'not', 'me', 'you', 'are', 'looking', 'at', 'Not', 'me', 'you', 'are', 'grinning', 'at', 'not', 'me', 'your', 'confidential', 'looks', 'Incriminate', 'but', 'that', 'other', 'person', 'if', 'person', 'You', 'thought', 'I', 'was', 'let', 'your', 'necrophily', 'Feed', 'upon', 'that', 'carcase', '', '', 'Prologue', 'I', 'am', 'an', 'invisible', 'man', 'No', 'I', 'am', 'not', 'a', 'spook', 'like', 'those', 'who', 'haunted', 'Edgar', 'Allan', 'Poe', 'nor', 'am', 'I', 'one', 'of', 'your', 'Hollywood-movie', 'ectoplasms', 'I', 'am', 'a', 'man', 'of']
# Invisible Man You are saved cried Captain Delano more and more astonished and pained you are saved what has cast such a shadow upon you HARRY I tell you it is not me you are looking at Not me you are grinning at not me your confidential looks Incriminate but that other person if person You thought I was let your necrophily Feed upon that carcase   Prologue I am an invisible man No I am not a spook like those who haunted Edgar Allan Poe nor am I one of your Hollywood-movie ectoplasms I am a man of substance of flesh and bone fiber and liquids -- and I might even be said to possess a mind I am invisible understand simply because people refuse to see me Like the bodiless heads you see sometimes in circus sideshows it is as though I have been surrounded by mirrors of hard distorting glass When they approach me they see only my surroundings themselves or figments of their imagination -- indeed everything and anything except me Nor is my invisibility exactly a matter of a bio-chemical accide

# %%
f = open("gutenberg_dict.txt", "r")

documentB = f.read().split()

f.close()

for i in range(0, len(documentB)):
    documentB[i] = documentB[i].strip(".,!?;:\'\"\(\)")

print(documentB[0:100])

documentB = " ".join(documentB)

print(documentB[0:1000])
# Out:
# ['A', 'A', 'named', 'a', 'in', 'the', 'English', 'and', 'most', 'commonly', 'ä', 'in', 'other', 'languages', 'Defn', 'The', 'first', 'letter', 'of', 'the', 'English', 'and', 'of', 'many', 'other', 'alphabets', 'The', 'capital', 'A', 'of', 'the', 'alphabets', 'of', 'Middle', 'and', 'Western', 'Europe', 'as', 'also', 'the', 'small', 'letter', 'a', 'besides', 'the', 'forms', 'in', 'Italic', 'black', 'letter', 'etc', 'are', 'all', 'descended', 'from', 'the', 'old', 'Latin', 'A', 'which', 'was', 'borrowed', 'from', 'the', 'Greek', 'Alpha', 'of', 'the', 'same', 'form', 'and', 'this', 'was', 'made', 'from', 'the', 'first', 'letter', 'Aleph', 'and', 'itself', 'from', 'the', 'Egyptian', 'origin', 'The', 'Aleph', 'was', 'a', 'consonant', 'letter', 'with', 'a', 'guttural', 'breath', 'sound', 'that', 'was', 'not', 'an']
# A A named a in the English and most commonly ä in other languages Defn The first letter of the English and of many other alphabets The capital A of the alphabets of Middle and Western Europe as also the small letter a besides the forms in Italic black letter etc are all descended from the old Latin A which was borrowed from the Greek Alpha of the same form and this was made from the first letter Aleph and itself from the Egyptian origin The Aleph was a consonant letter with a guttural breath sound that was not an element of Greek articulation and the Greeks took it to represent their vowel Alpha with the ä sound the Phoenician alphabet having no vowel symbols This letter in English is used for several different vowel sounds See Guide to pronunciation §§ 43-74 The regular long a as in fate etc is a comparatively modern sound and has taken the place of what till about the early part of the 17th century was a sound of the quality of ä as in far 2 Mus Defn The name of the sixth tone in the

# %%
vectorizer = TfidfVectorizer()
vectors = vectorizer.fit_transform([documentA, documentB])
feature_names = vectorizer.get_feature_names()
dense = vectors.todense()
denselist = dense.tolist()
df = pd.DataFrame(denselist, columns=feature_names)

# %%
third = []

for word in df:
    if df.at[0, word] > 10 * df.at[1, word] and word not in stopwords.words('english') and not word.isnumeric():
        third.append(word)

# %%
print(third)
# Out:
# ['110th', '123rd', '125th', '42nd', 'aaaah', 'abetted', 'abiding', 'aboil', 'abso', 'abstractedly', 'accounta', 'ached', 'aches', 'aching', 'acidly', 'acoustical', 'acrosis', 'adolescence', 'ads', 'advertising', 'aer', 'afire', 'aflame', 'afraid', 'afrian', 'afro', 'afternoon', 'afternoons', 'aggressively', 'aggressiveness', 'agin', 'aglow', 'ago', 'ahction', 'ahead', 'ahere', 'ahm', 'aimin', 'airfield', 'airless', 'airplane', 'airshaft', 'alerted', 'alger', 'aliveness', 'allan', 'aloofness', 'alpacas', 'already', 'amazed', 'amazingly', 'ambitions', 'ambivalence', 'amplifier', 'amused', 'analyst', 'ands', 'andy', 'angrier', 'angrily', 'angry', 'anguished', 'ankles', 'announcements', 'annoyed', 'anonymity', 'anonymous', 'anteroom', 'anybody', 'anyhow', 'anyone', 'anytime', 'anyway', 'apologies', 'apologize', 'apologized', 'appeared', 'appraising', 'approached', 'aproned', 'aprons', 'aquarium', 'areaway', 'areaways', 'arena', 'arguing', 'armful', 'armistice', 'armpits', 'armstrong', 'aroar', 'arose', 'around', 'aroused', 'arpeggios', 'ascot', 'ase', 'ashamed', 'asked', 'askin', 'aspirations', 'aspired', 'asset', 'assignment', 'assortments', 'atop', 'attitudes', 'attuned', 'audience', 'audiences', 'automat', 'avenue', 'avenues', 'aw', 'awaited', 'awaiting', 'aware', 'awareness', 'awash', 'awfully', 'awhile', 'awhirl', 'awoke', 'ayes', 'baabay', 'babies', 'baby', 'babyishly', 'backfire', 'background', 'backing', 'backlight', 'backwardness', 'backwards', 'backwash', 'backyards', 'bafflement', 'bags', 'bahd', 'bahstard', 'bahstards', 'balcony', 'ballantine', 'ballbearing', 'balled', 'ballooned', 'ballroom', 'balustrade', 'bananas', 'bandanna', 'bandmaster', 'banging', 'bangs', 'banked', 'banknote', 'banners', 'banteringly', 'barbee', 'barbour', 'bareface', 'barefoot', 'barely', 'barges', 'baritone', 'barked', 'barrage', 'barrelhouse', 'bartender', 'basement', 'bashing', 'basically', 'bastards', 'batch', 'bates', 'bathed', 'bathroom', 'bathtub', 'bawn', 'baying', 'beatin', 'beca', 'became', 'beckoning', 'bedbugs', 'bedmate', 'bedroom', 'bedspread', 'beefing', 'beefy', 'beers', 'befo', 'began', 'belatedly', 'believe', 'belilve', 'belligerently', 'bellowed', 'bemused', 'benches', 'benefited', 'beside', 'betrayal', 'betrayer', 'bettering', 'bewilderment', 'bibles', 'biddy', 'biff', 'big', 'biggest', 'biggity', 'bigshots', 'bility', 'bindings', 'binoculars', 'bio', 'birmingham', 'birthed', 'bitch', 'blackboard', 'blacker', 'blackjacked', 'blackness', 'blahsted', 'blaming', 'blandly', 'blanging', 'blangy', 'blankly', 'blared', 'blaring', 'blazing', 'bleary', 'bled', 'bledsoe', 'bledsoes', 'bledsoing', 'bleedin', 'blindfolded', 'blindfolds', 'blinding', 'blindly', 'blinked', 'blinking', 'blip', 'blobs', 'blocked', 'blocking', 'blond', 'blonde', 'bloomed', 'blossomy', 'blubberheads', 'blueprint', 'blueprints', 'blues', 'bluffing', 'blundered', 'blurred', 'blurrily', 'blurted', 'boatwright', 'bobbing', 'bobby', 'bombarded', 'bomination', 'boo', 'boogey', 'boogie', 'boogieful', 'boogy', 'bookcase', 'bookcases', 'booker', 'bookety', 'bookshelf', 'boomed', 'boomerang', 'boomeranged', 'boomeranging', 'booo', 'booooo', 'boooooo', 'bootlegger', 'borden', 'bossing', 'bostonian', 'bother', 'bothered', 'bothering', 'bounce', 'bounced', 'bouncy', 'bourbon', 'bourbons', 'bout', 'bowlegged', 'boy', 'boys', 'brads', 'brashly', 'breakin', 'breathin', 'breathtaking', 'breezing', 'brer', 'brightened', 'brims', 'bristled', 'britches', 'broadcasting', 'broadened', 'broadnax', 'broadway', 'brockway', 'broke', 'brooded', 'brother', 'brotherhood', 'brothers', 'brownstone', 'bruiser', 'brushed', 'brushing', 'brutally', 'bucket', 'buckets', 'buckeye', 'buckshot', 'buddies', 'buddy', 'budweiser', 'bugled', 'bugler', 'bugles', 'buked', 'bulged', 'bullets', 'bullfight', 'bullshit', 'bumped', 'bumping', 'bungled', 'bunnies', 'bureaucrats', 'burglar', 'burglars', 'burnin', 'burnside', 'businessmen', 'busses', 'buster', 'bustin', 'buts', 'butted', 'buttered', 'buzzed',  ...

# %%
print(len(third))
# Out:
# 2880

# %%
third = []

for word in df:
    if df.at[0, word] > df.at[1, word] and word not in stopwords.words('english') and not word.isnumeric():
        third.append(word)

# %%
print(third)
# Out:
# ['110th', '123rd', '125th', '42nd', 'aaaah', 'aback', 'abashed', 'abetted', 'abiding', 'abilities', 'ablaze', 'aboard', 'aboil', 'abraham', 'abreast', 'abruptly', 'abso', 'absolutely', 'absorbent', 'absorbing', 'absorption', 'abstract', 'abstractedly', 'absurd', 'absurdity', 'absurdly', 'abusing', 'abysmal', 'abyssinian', 'accelerated', 'acceleration', 'accents', 'accept', 'acceptance', 'accepted', 'accepting', 'accessible', 'accident', 'accidentally', 'accordion', 'accounta', 'accumulated', 'accuse', 'accused', 'accusing', 'ache', 'ached', 'aches', 'achieve', 'achieved', 'achievement', 'achievements', 'achieving', 'aching', 'acidly', 'acoustical', 'acquainted', 'acrosis', 'across', 'acted', 'acting', 'actors', 'actually', 'adding', 'address', 'addressed', 'addressing', 'adequately', 'adhesive', 'adjourned', 'administrative', 'admiration', 'admirer', 'admiring', 'admits', 'adolescence', 'adoring', 'ads', 'adults', 'advancing', 'advantageous', 'adventures', 'advertising', 'advice', 'advise', 'advised', 'adviser', 'aer', 'affidavit', 'affirm', 'affirmation', 'affirming', 'afford', 'afire', 'aflame', 'afraid', 'afrian', 'afro', 'afternoon', 'afternoons', 'afterwards', 'agape', 'aggregation', 'aggressive', 'aggressively', 'aggressiveness', 'agin', 'agitated', 'agitator', 'aglow', 'ago', 'agonizing', 'agony', 'agrarian', 'agree', 'agreed', 'ah', 'aha', 'ahction', 'ahead', 'ahere', 'ahm', 'aided', 'aids', 'aim', 'aimed', 'aimin', 'aiming', 'aims', 'air', 'airfield', 'airless', 'airplane', 'airshaft', 'aisle', 'akimbo', 'alabama', 'alarmed', 'alarming', 'alarms', 'alas', 'albert', 'albino', 'alert', 'alerted', 'algae', 'alger', 'alien', 'alight', 'alive', 'aliveness', 'allan', 'alley', 'alliances', 'allies', 'allow', 'allowed', 'allowing', 'allows', 'alma', 'almost', 'alone', 'along', 'alongside', 'aloofness', 'aloud', 'alpacas', 'alphabets', 'already', 'alternative', 'although', 'always', 'amazed', 'amazement', 'amazing', 'amazingly', 'amazon', 'ambiguity', 'ambiguous', 'ambition', 'ambitions', 'ambivalence', 'ambulance', 'amen', 'americans', 'amos', 'amplifier', 'amputated', 'amused', 'amusement', 'analyst', 'analytical', 'analyzed', 'anarchy', 'anchored', 'ands', 'andy', 'anger', 'angered', 'angrier', 'angrily', 'angry', 'anguish', 'anguished', 'ankle', 'ankles', 'announced', 'announcements', 'announcing', 'annoyance', 'annoyed', 'annoying', 'anonymity', 'anonymous', 'another', 'answer', 'answered', 'answering', 'answers', 'antagonism', 'antagonize', 'anteroom', 'anticipatory', 'antiphonal', 'antithesis', 'anxiety', 'anxious', 'anxiously', 'anybody', 'anyhow', 'anyone', 'anytime', 'anyway', 'anywhere', 'apart', 'apartment', 'apologies', 'apologize', 'apologized', 'apoplexy', 'appeal', 'appeals', 'appeared', 'applaud', 'applauding', 'applause', 'appointment', 'appointments', 'appraising', 'appreciate', 'appreciated', 'appreciation', 'approach', 'approached', 'approaching', 'approval', 'apron', 'aproned', 'aprons', 'aquarium', 'arched', 'arching', 'architect', 'area', 'areas', 'areaway', 'areaways', 'arena', 'argue', 'argued', 'arguing', 'arise', 'arisen', 'aristocrat', 'aristocratic', 'arm', 'armful', 'armistice', 'armored', 'armory', 'armpits', 'arms', 'armstrong', 'aroar', 'arose', 'around', 'arouse', 'aroused', 'arousing', 'arpeggios', 'arrayed', 'arrested', 'arresting', 'arrived', 'arrogance', 'arrogant', 'arsenal', 'articulate', 'articulated', 'ascot', 'ase', 'ashamed', 'ashy', 'aside', 'ask', 'asked', 'askin', 'asking', 'asks', 'asleep', 'aspects', 'asphalt', 'aspirations', 'aspire', 'aspired', 'ass', 'assembled', 'asserting', 'asset', 'assigned', 'assignment', 'assistant', 'assisted', 'assortments', 'assumption', 'assurance', 'assure', 'assured', 'assuring', 'astonished', 'astound', 'astounding', 'asylum', 'athlete', 'atlanta', 'atop', 'atrophied', 'attack', 'attacked', 'attacking', 'attempted', 'attempting', 'attend', 'attendant', 'attending', 'attention', 'attest', 'attitude', 'attitudes', 'attract', 'attracted', 'attracti ...

# %%
print(len(third))
# Out:
# 7977

# %%
f = open("invman_tfidf_results.txt", "w")

f.write(", ".join(third))

f.close()

# %%
f = open("gbg.txt", "r")

documentA = f.read().split()

f.close()

for i in range(0, len(documentA)):
    documentA[i] = documentA[i].strip(".,!?;:\'\"\(\)")

print(documentA[0:100])

documentA = " ".join(documentA)

print(documentA[0:1000])
# Out:
# ['Magister', 'Ludi', 'The', 'Glass', 'Bead', 'Game', 'by', 'Hermann', 'Hesse', '1943', 'Translated', 'from', 'the', 'German', 'Das', 'Glasperlenspiel', 'by', 'Richard', 'and', 'Clard', 'Winston', 'with', 'a', 'Forword', 'by', 'Theodore', 'Ziolkowski', 'THE', 'GLASS', 'BEAD', 'GAME', 'A', 'tentative', 'sketch', 'of', 'the', 'life', 'of', 'Magister', 'Ludi', 'Joseph', 'Knecht', 'together', 'with', "Knecht's", 'posthumous', 'writings', 'edited', 'by', 'HERMANN', 'HESSE', 'dedicated', 'to', 'the', 'Journeyers', 'to', 'the', 'East', 'CONTENTS', 'The', 'Glass', 'Bead', 'Game', 'A', 'General', 'Introduction', 'to', 'Its', 'History', 'for', 'the', 'Layman', 'The', 'Life', 'of', 'Magister', 'Ludi', 'Joseph', 'Knecht', '1', 'The', 'Call', '2', 'Waldzell', '3', 'Years', 'of', 'Freedom', '4', 'Two', 'Orders', '5', 'The', 'Mission', '6', 'Magister', 'Ludi', '7', 'In', 'Office']
# Magister Ludi The Glass Bead Game by Hermann Hesse 1943 Translated from the German Das Glasperlenspiel by Richard and Clard Winston with a Forword by Theodore Ziolkowski THE GLASS BEAD GAME A tentative sketch of the life of Magister Ludi Joseph Knecht together with Knecht's posthumous writings edited by HERMANN HESSE dedicated to the Journeyers to the East CONTENTS The Glass Bead Game A General Introduction to Its History for the Layman The Life of Magister Ludi Joseph Knecht 1 The Call 2 Waldzell 3 Years of Freedom 4 Two Orders 5 The Mission 6 Magister Ludi 7 In Office 8 The Two Poles 9 A Conversation 10 Preparations 11 The Circular Letter 12 The Legend Joseph Knecht's Posthumous Writings The Poems of Knecht's Student Years The Three Lives 1 The Rainmaker 2 The Father Confessor 3 The Indian Life THE GLASS BEAD GAME A GENERAL INTRODUCTION TO ITS HISTORY FOR THE LAYMAN   Non entia enim licet quodammodo levibusque hominibus facilius atque incuriosius verbis reddere quam entia veruntamen

# %%
vectorizer = TfidfVectorizer()
vectors = vectorizer.fit_transform([documentA, documentB])
feature_names = vectorizer.get_feature_names()
dense = vectors.todense()
denselist = dense.tolist()
df = pd.DataFrame(denselist, columns=feature_names)

# %%
third = []

for word in df:
    if df.at[0, word] > 10 * df.at[1, word] and word not in stopwords.words('english') and not word.isnumeric():
        third.append(word)

# %%
print(third)
# Out:
# ['abbeys', 'abbreviations', 'abelard', 'abided', 'abnormalities', 'abnormality', 'absently', 'absentness', 'absorbedly', 'abstractions', 'abysses', 'academics', 'academies', 'acceptably', 'accepting', 'accorded', 'ached', 'aches', 'achieved', 'achievements', 'acidly', 'acolytes', 'acquaintances', 'acquainting', 'acquiescing', 'activa', 'activating', 'actually', 'acuity', 'ada', 'adaptations', 'adeo', 'adepts', 'adjustments', 'admired', 'admirers', 'admiring', 'admonished', 'admonishments', 'adoring', 'adroitly', 'adulating', 'advising', 'aegis', 'aeon', 'aeons', 'aesthetes', 'aesthetic', 'aestheticism', 'aesthetics', 'affably', 'afire', 'aforementioned', 'aftertaste', 'ageless', 'agenda', 'aging', 'aglow', 'ago', 'agora', 'aides', 'aiready', 'airless', 'albertus', 'albrecht', 'alerted', 'alertness', 'alessandro', 'alex', 'alexander', 'alighted', 'aligned', 'aliter', 'allegedly', 'allusions', 'almost', 'aloofness', 'alphabets', 'already', 'although', 'altogether', 'altruism', 'amadeus', 'amateurish', 'amateurishness', 'amateurs', 'amazingly', 'ambience', 'ambitions', 'ambitious', 'amenities', 'amiably', 'amok', 'amor', 'amounted', 'ampler', 'amulets', 'amused', 'amusingly', 'analogies', 'analyses', 'analyzes', 'ancestress', 'andrea', 'andré', 'anecdotal', 'anguished', 'angusta', 'animatedly', 'anniversarius', 'annoyingly', 'anonymity', 'antiche', 'antichrist', 'anticlerical', 'antihistorical', 'antimystical', 'antinomies', 'antipodal', 'antitheses', 'anton', 'anxieties', 'anxiously', 'anyhow', 'anyone', 'aplenty', 'apologetically', 'apologized', 'apostates', 'appeared', 'appreciatively', 'apprentices', 'apprenticeship', 'approached', 'appropinquant', 'aptitudes', 'aquinas', 'arbors', 'arcades', 'archaeologists', 'archangels', 'archive', 'archives', 'archivist', 'archivists', 'aristocratic', 'aristocratically', 'armaments', 'armchair', 'arrived', 'artificiosam', 'artisans', 'artistically', 'artistry', 'ascalon', 'ascetic', 'ascetically', 'asceticism', 'ascetics', 'asked', 'aspects', 'aspirants', 'aspirations', 'assailed', 'assaults', 'assessing', 'assignment', 'assignments', 'assistants', 'associates', 'associations', 'astonished', 'astonishes', 'astonishing', 'astonishingly', 'astounding', 'atque', 'atrocities', 'attentiveness', 'attitude', 'attitudes', 'attracted', 'attractively', 'attune', 'audiences', 'aunts', 'aura', 'autem', 'authorities', 'autobiography', 'aversions', 'aviators', 'avidissimum', 'avuncular', 'awaited', 'awaiting', 'awaits', 'awakened', 'awakening', 'awakenings', 'awards', 'aware', 'awareness', 'awfully', 'awoke', 'babbled', 'bacchantic', 'bach', 'backgrounds', 'bade', 'balkan', 'bamboo', 'bamboos', 'banal', 'bandied', 'banned', 'barbarities', 'barbarization', 'baroque', 'barrage', 'barriers', 'basel', 'basically', 'basiliensis', 'basked', 'basses', 'bastian', 'battened', 'battlefronts', 'baubles', 'bead', 'bearable', 'became', 'beckoned', 'bedazzled', 'bedazzlement', 'bedtime', 'began', 'beginners', 'beginnings', 'behaved', 'behaves', 'behooved', 'belatedly', 'beliefs', 'belittling', 'belligerently', 'bellnote', 'bellowed', 'belonged', 'belpunt', 'bemused', 'benedictine', 'benedictines', 'benefiting', 'bengel', 'benignly', 'berolfingen', 'berserk', 'bertram', 'bestiality', 'betokened', 'betrayal', 'betrayer', 'bewilderingly', 'bidding', 'bigwigs', 'bilberries', 'bildungsroman', 'biographer', 'biographers', 'biographical', 'biographies', 'biography', 'bitterest', 'blamed', 'blaming', 'blandly', 'blankly', 'blared', 'blasé', 'bleakly', 'bleakness', 'blinked', 'blissfully', 'blocked', 'blocs', 'bloodlettings', 'blossomed', 'blueness', 'blundered', 'blunderer', 'bluntly', 'blurrings', 'bolzano', 'bombarded', 'booklet', 'boredom', 'bothered', 'bothersome', 'boulders', 'boundlessness', 'bourgeoisie', 'boy', 'boyhood', 'boyish', 'boyishly', 'brahman', 'brahmans', 'brashness', 'breached', 'breaches', 'breakthrough', 'breathable', 'breaths', 'bremgarten', 'briefest', 'briefing', 'briefly', 'brightened', 'brilliance ...

# %%
print(len(third))
# Out:
# 2928

# %%
third = []

for word in df:
    if df.at[0, word] > df.at[1, word] and word not in stopwords.words('english') and not word.isnumeric():
        third.append(word)

# %%
print(third)
# Out:
# ['aback', 'abacus', 'abandon', 'abandoned', 'abandoning', 'abashed', 'abbey', 'abbeys', 'abbot', 'abbreviations', 'abelard', 'abided', 'abides', 'abilities', 'ability', 'able', 'abler', 'abnormalities', 'abnormality', 'abolishing', 'abomination', 'abrupt', 'abruptly', 'absently', 'absentness', 'absolute', 'absolutely', 'absolution', 'absorbed', 'absorbedly', 'absorbing', 'absorbs', 'absorption', 'abstain', 'abstained', 'abstemious', 'abstract', 'abstracted', 'abstraction', 'abstractions', 'abstruse', 'abstruseness', 'absurdity', 'abused', 'abyss', 'abysses', 'academic', 'academics', 'academies', 'academy', 'accelerated', 'accelerating', 'accentual', 'accept', 'acceptable', 'acceptably', 'acceptance', 'accepted', 'accepting', 'accepts', 'accessible', 'accompanied', 'accompany', 'accomplished', 'accomplishment', 'accomplishments', 'accord', 'accorded', 'accordingly', 'accords', 'accountable', 'accounting', 'accumulated', 'accursed', 'accusations', 'accustomed', 'acerbity', 'ached', 'aches', 'achieve', 'achieved', 'achievement', 'achievements', 'aching', 'acidly', 'acknowledge', 'acknowledged', 'acknowledges', 'acknowledging', 'acolytes', 'acquaintance', 'acquaintances', 'acquainted', 'acquainting', 'acquiescing', 'acquired', 'acquires', 'acquiring', 'acrobat', 'acrobatic', 'acted', 'activa', 'activating', 'active', 'activities', 'activity', 'actors', 'actually', 'acuity', 'acutely', 'ada', 'adam', 'adaptations', 'adapts', 'add', 'added', 'addition', 'additional', 'additions', 'address', 'addressed', 'addressing', 'adeo', 'adept', 'adepts', 'adequately', 'adherents', 'adjustments', 'administered', 'administering', 'administrative', 'administrator', 'admirably', 'admiration', 'admire', 'admired', 'admirer', 'admirers', 'admires', 'admiring', 'admission', 'admit', 'admitted', 'admonished', 'admonishments', 'admonition', 'admonitions', 'admonitory', 'ado', 'adolescence', 'adoration', 'adored', 'adoring', 'adrian', 'adroitly', 'adulating', 'adulation', 'adultery', 'adults', 'advanced', 'advances', 'advantages', 'adventitious', 'adventurer', 'adventurers', 'adventures', 'adversaries', 'adversely', 'advice', 'advisable', 'advised', 'adviser', 'advisers', 'advises', 'advising', 'advocated', 'advocates', 'aegis', 'aeon', 'aeons', 'aesthetes', 'aesthetic', 'aestheticism', 'aesthetics', 'afar', 'affable', 'affably', 'affair', 'affairs', 'affectionate', 'affectionately', 'affiliated', 'affirm', 'affirmation', 'afflicted', 'afforded', 'afield', 'afire', 'aforementioned', 'afraid', 'afternoon', 'aftertaste', 'afterward', 'age', 'aged', 'ageless', 'agenda', 'ages', 'aggressive', 'agility', 'aging', 'aglow', 'ago', 'agog', 'agonies', 'agony', 'agora', 'agreed', 'agrees', 'aground', 'ah', 'ahead', 'aide', 'aided', 'aides', 'aids', 'ailing', 'aimed', 'aimless', 'aims', 'aiready', 'airless', 'alarm', 'alarmed', 'alarming', 'albertus', 'albrecht', 'album', 'alchemical', 'alchemy', 'alert', 'alerted', 'alertness', 'alessandro', 'alex', 'alexander', 'alexandrian', 'alien', 'alienated', 'alienation', 'alighted', 'aligned', 'aliter', 'alive', 'allegedly', 'alleviated', 'alleviation', 'alliance', 'allotment', 'allow', 'allowed', 'allowing', 'alluring', 'allusions', 'almost', 'alone', 'along', 'alongside', 'aloof', 'aloofness', 'aloud', 'alphabets', 'already', 'alterable', 'alternately', 'alternating', 'alternation', 'alternations', 'although', 'altogether', 'altruism', 'always', 'amadeus', 'amateur', 'amateurish', 'amateurishness', 'amateurs', 'amazed', 'amazement', 'amazing', 'amazingly', 'ambassadors', 'ambience', 'ambition', 'ambitions', 'ambitious', 'amenities', 'amiability', 'amiable', 'amiably', 'amice', 'amid', 'amity', 'amnesty', 'amok', 'among', 'amor', 'amounted', 'amounting', 'amounts', 'ampler', 'amputated', 'amulets', 'amuse', 'amused', 'amusement', 'amusements', 'amusing', 'amusingly', 'analogies', 'analyses', 'analysis', 'analytical', 'analyze', 'analyzed', 'analyzes', 'analyzing', 'anatomical', 'anatomist', 'ancestress', 'ancient', 'anda ...

# %%
print(len(third))
# Out:
# 9211

# %%
f = open("gbg_tfidf_results.txt", "w")

f.write(", ".join(third))

f.close()
