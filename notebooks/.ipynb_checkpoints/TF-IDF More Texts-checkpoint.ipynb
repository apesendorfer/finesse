# %%
# https://towardsdatascience.com/natural-language-processing-feature-engineering-using-tf-idf-e8b9d00e7e76

import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
from nltk.corpus import stopwords
# stopwords.words('english')

# %%
f = open("gatsby.txt", "r")

documentA = f.read().split()

f.close()

for i in range(0, len(documentA)):
    documentA[i] = documentA[i].strip(".,!?;:\'\"\[\]\*\#")
    #documentA[i] = documentA[i].strip(".,!?;:\"\[\]\*\#")

print(documentA[0:100])

documentA = " ".join(documentA)

print(documentA[0:1000])
# Out:
# ['\ufeffThe', 'Project', 'Gutenberg', 'eBook', 'of', 'The', 'Great', 'Gatsby', 'by', 'F', 'Scott', 'Fitzgerald', 'This', 'eBook', 'is', 'for', 'the', 'use', 'of', 'anyone', 'anywhere', 'in', 'the', 'United', 'States', 'and', 'most', 'other', 'parts', 'of', 'the', 'world', 'at', 'no', 'cost', 'and', 'with', 'almost', 'no', 'restrictions', 'whatsoever', 'You', 'may', 'copy', 'it', 'give', 'it', 'away', 'or', 're-use', 'it', 'under', 'the', 'terms', 'of', 'the', 'Project', 'Gutenberg', 'License', 'included', 'with', 'this', 'eBook', 'or', 'online', 'at', 'www.gutenberg.org', 'If', 'you', 'are', 'not', 'located', 'in', 'the', 'United', 'States', 'you', 'will', 'have', 'to', 'check', 'the', 'laws', 'of', 'the', 'country', 'where', 'you', 'are', 'located', 'before', 'using', 'this', 'eBook', 'Title', 'The', 'Great', 'Gatsby', 'Author', 'F']
# ...

# %%
f = open("gutenberg_dict.txt", "r")

documentB = f.read().split()

f.close()

for i in range(0, len(documentB)):
    documentB[i] = documentB[i].strip(".,!?;:\'\"\(\)")

print(documentB[0:100])

documentB = " ".join(documentB)

print(documentB[0:1000])
# Out:
# ['A', 'A', 'named', 'a', 'in', 'the', 'English', 'and', 'most', 'commonly', 'ä', 'in', 'other', 'languages', 'Defn', 'The', 'first', 'letter', 'of', 'the', 'English', 'and', 'of', 'many', 'other', 'alphabets', 'The', 'capital', 'A', 'of', 'the', 'alphabets', 'of', 'Middle', 'and', 'Western', 'Europe', 'as', 'also', 'the', 'small', 'letter', 'a', 'besides', 'the', 'forms', 'in', 'Italic', 'black', 'letter', 'etc', 'are', 'all', 'descended', 'from', 'the', 'old', 'Latin', 'A', 'which', 'was', 'borrowed', 'from', 'the', 'Greek', 'Alpha', 'of', 'the', 'same', 'form', 'and', 'this', 'was', 'made', 'from', 'the', 'first', 'letter', 'Aleph', 'and', 'itself', 'from', 'the', 'Egyptian', 'origin', 'The', 'Aleph', 'was', 'a', 'consonant', 'letter', 'with', 'a', 'guttural', 'breath', 'sound', 'that', 'was', 'not', 'an']
# ...

# %%
vectorizer = TfidfVectorizer()
vectors = vectorizer.fit_transform([documentA, documentB])
feature_names = vectorizer.get_feature_names()
dense = vectors.todense()
denselist = dense.tolist()
df = pd.DataFrame(denselist, columns=feature_names)

# %%
third = []

for word in df:
    if df.at[0, word] > 10 * df.at[1, word] and word not in stopwords.words('english') and not word.isnumeric():
        third.append(word)

# %%
print(third)
# Out:
# ['158th', '33rd', 'abounded', 'abrams', 'abruptly', 'absently', 'absolutely', 'abstractedly', 'accelerator', 'accentuated', 'accepted', 'access', 'accessed', 'accounting', 'accusations', 'accusingly', 'aching', 'acquaintances', 'actress', 'adapting', 'addenda', 'addresses', 'admired', 'admiringly', 'adorable', 'adriatic', 'advertisement', 'advised', 'aesthetic', 'affectations', 'afraid', 'afternoon', 'afternoons', 'aggressively', 'ago', 'agonizingly', 'agreed', 'ahead', 'aired', 'airedale', 'ajar', 'alarmed', 'albany', 'albrucksburger', 'alertly', 'alex', 'alighted', 'alleys', 'alone', 'alongshore', 'alongside', 'aloud', 'already', 'amazed', 'amazing', 'ambiguously', 'ambitions', 'ambulance', 'americans', 'amputated', 'amused', 'anaemic', 'announced', 'annoyed', 'answered', 'antecedents', 'anteroom', 'anticlimax', 'antly', 'antoinette', 'anxiously', 'anybody', 'anyhow', 'anyone', 'anyways', 'anywhere', 'apathetically', 'apologetically', 'apologize', 'appalled', 'appalling', 'appeared
# ...

# %%
print(len(third))
# Out:
# 2038

# %%
third = []

for word in df:
    if df.at[0, word] > df.at[1, word] and word not in stopwords.words('english') and not word.isnumeric():
        third.append(word)

# %%
print(third)
# Out:
# ['158th', '33rd', '5th', 'abandon', 'abandoned', 'abide', 'able', 'abnormal', 'abortive', 'abounded', 'abrams', 'abrupt', 'abruptly', 'absence', 'absent', 'absently', 'absolute', 'absolutely', 'absorbed', 'absorbing', 'absorption', 'abstracted', 'abstractedly', 'abstraction', 'absurd', 'abyss', 'accelerator', 'accentuated', 'accept', 'accepted', 'accepting', 'access', 'accessed', 'accessible', 'accident', 'accidental', 'accidentally', 'accompanies', 'accomplishments', 'accordance', 'accounted', 'accounting', 'accusations', 'accused', 'accusingly', 'achievement', 'aching', 'acknowledged', 'acquaintance', 'acquaintances', 'acre', 'acres', 'across', 'activities', 'actor', 'actress', 'actual', 'actually', 'acute', 'adam', 'adapting', 'added', 'addenda', 'adding', 'additional', 'additions', 'address', 'addressed', 'addresses', 'addressing', 'adjusted', 'adjustment', 'admiration', 'admire', 'admired', 'admiringly', 'admission', 'admitted', 'adorable', 'adore', 'adriatic', 'advancing', 'adv
# ...

# %%
print(len(third))
# Out:
# 4915

# %%
f = open("gatsby_tfidf_results.txt", "w")

f.write(", ".join(third))

f.close()

# %%
f = open("frankenstein.txt", "r")

documentA = f.read().split()

f.close()

for i in range(0, len(documentA)):
    documentA[i] = documentA[i].strip(".,!?;:\'\"\(\)\[\]\*_")

print(documentA[0:100])

documentA = " ".join(documentA)

print(documentA[0:1000])
# Out:
# ['\ufeffThe', 'Project', 'Gutenberg', 'EBook', 'of', 'Frankenstein', 'by', 'Mary', 'W', 'Shelley', 'This', 'eBook', 'is', 'for', 'the', 'use', 'of', 'anyone', 'anywhere', 'at', 'no', 'cost', 'and', 'with', 'almost', 'no', 'restrictions', 'whatsoever', 'You', 'may', 'copy', 'it', 'give', 'it', 'away', 'or', 're-use', 'it', 'under', 'the', 'terms', 'of', 'the', 'Project', 'Gutenberg', 'License', 'included', 'with', 'this', 'eBook', 'or', 'online', 'at', 'www.gutenberg.org', 'Title', 'Frankenstein', 'or', 'The', 'Modern', 'Prometheus', 'Author', 'Mary', 'W', 'Shelley', 'Release', 'Date', 'March', '13', '2013', 'EBook', '#42324', 'Language', 'English', '', 'START', 'OF', 'THIS', 'PROJECT', 'GUTENBERG', 'EBOOK', 'FRANKENSTEIN', '', 'Produced', 'by', 'Greg', 'Weeks', 'Mary', 'Meehan', 'and', 'the', 'Online', 'Distributed', 'Proofreading', 'Team', 'at', 'http://www.pgdp.net', 'FRANKENSTEIN', 'OR', 'THE', 'MODERN']
# ...

# %%
vectorizer = TfidfVectorizer()
vectors = vectorizer.fit_transform([documentA, documentB])
feature_names = vectorizer.get_feature_names()
dense = vectors.todense()
denselist = dense.tolist()
df = pd.DataFrame(denselist, columns=feature_names)

# %%
third = []

for word in df:
    if df.at[0, word] > 10 * df.at[1, word] and word not in stopwords.words('english') and not word.isnumeric():
        third.append(word)

# %%
print(third)
# Out:
# ['26th', '27th', '28th', '31st', '7th', '_i', 'abhor', 'abhorred', 'acceded', 'accents', 'accessed', 'accidents', 'accorded', 'accordingly', 'accursed', 'aching', 'acquaintances', 'acquainted', 'acquiesced', 'adduced', 'admiration', 'adored', 'adorns', 'aerial', 'affectionate', 'afforded', 'agatha', 'agitates', 'agonies', 'agonised', 'agonising', 'agony', 'agrippa', 'aided', 'aiguilles', 'alarmed', 'alas', 'albertus', 'alchymists', 'alighted', 'alighting', 'alleging', 'alleviated', 'allured', 'allurements', 'aloud', 'alphonse', 'already', 'alterations', 'although', 'amassed', 'amiable', 'amiableness', 'amidst', 'amounted', 'amphitheatre', 'analysing', 'anatomise', 'anguish', 'annihilation', 'annoyed', 'anticipations', 'anxiously', 'anyone', 'appalling', 'appeared', 'apprehensions', 'approached', 'arabian', 'arbiters', 'archangel', 'archive', 'ardently', 'ardour', 'ariosto', 'armour', 'arose', 'arranging', 'arrived', 'arrowy', 'arve', 'arveiron', 'ascended', 'ascii', 'asiatics', 'aske
# ...

# %%
print(len(third))
# Out:
# 1542

# %%
third = []

for word in df:
    if df.at[0, word] > df.at[1, word] and word not in stopwords.words('english') and not word.isnumeric():
        third.append(word)

# %%
print(third)
# Out:
# ['11th', '12th', '13th', '18th', '26th', '27th', '28th', '31st', '5th', '7th', '9th', '_i', 'abandon', 'abandoned', 'abbey', 'abhor', 'abhorred', 'abhorrence', 'abhorrent', 'abject', 'able', 'aboard', 'abode', 'abortion', 'abortive', 'abroad', 'absence', 'absent', 'absolutely', 'absolution', 'absorbed', 'absorbing', 'abstained', 'abstruse', 'abyss', 'acceded', 'accent', 'accents', 'accept', 'acceptable', 'accepted', 'accepting', 'access', 'accessed', 'accessible', 'accident', 'accidentally', 'accidents', 'accompanied', 'accompany', 'accomplish', 'accomplished', 'accomplishment', 'accomplishments', 'accordance', 'accorded', 'accordingly', 'account', 'accounted', 'accounts', 'accumulated', 'accumulation', 'accuracy', 'accursed', 'accusations', 'accuse', 'accused', 'accuses', 'accustomed', 'achieve', 'achieved', 'achievements', 'aching', 'acknowledged', 'acme', 'acorns', 'acquaintances', 'acquainted', 'acquiesced', 'acquire', 'acquired', 'acquirement', 'acquiring', 'acquisition', 'acqui
# ...

# %%
print(len(third))
# Out:
# 5602

# %%
f = open("frankenstein_tfidf_results.txt", "w")

f.write(", ".join(third))

f.close()

# %%
# Moby-Dick

f = open("moby-dick.txt", "r")

documentA = f.read().split()

f.close()

for i in range(0, len(documentA)):
    documentA[i] = documentA[i].strip(".,!?;:\'\"\(\)\[\]\*_")

print(documentA[0:100])

documentA = " ".join(documentA)

print(documentA[0:1000])
# Out:
# ['\ufeffThe', 'Project', 'Gutenberg', 'eBook', 'of', 'Moby-Dick', 'by', 'Herman', 'Melville', 'This', 'eBook', 'is', 'for', 'the', 'use', 'of', 'anyone', 'anywhere', 'in', 'the', 'United', 'States', 'and', 'most', 'other', 'parts', 'of', 'the', 'world', 'at', 'no', 'cost', 'and', 'with', 'almost', 'no', 'restrictions', 'whatsoever', 'You', 'may', 'copy', 'it', 'give', 'it', 'away', 'or', 're-use', 'it', 'under', 'the', 'terms', 'of', 'the', 'Project', 'Gutenberg', 'License', 'included', 'with', 'this', 'eBook', 'or', 'online', 'at', 'www.gutenberg.org', 'If', 'you', 'are', 'not', 'located', 'in', 'the', 'United', 'States', 'you', 'will', 'have', 'to', 'check', 'the', 'laws', 'of', 'the', 'country', 'where', 'you', 'are', 'located', 'before', 'using', 'this', 'eBook', 'Title', 'Moby-Dick', 'Author', 'Herman', 'Melville', 'Release', 'Date', 'May', '1991']
# ...

# %%
vectorizer = TfidfVectorizer()
vectors = vectorizer.fit_transform([documentA, documentB])
feature_names = vectorizer.get_feature_names()
dense = vectors.todense()
denselist = dense.tolist()
df = pd.DataFrame(denselist, columns=feature_names)

# %%
third = []

for word in df:
    if df.at[0, word] > 10 * df.at[1, word] and word not in stopwords.words('english') and not word.isnumeric():
        third.append(word)

# %%
print(third)
# Out:
# ['1_st', '200th', '275th', '31_st', '3_d', '_a', '_all', '_apology', '_aside', '_baron', '_blackstone', '_broke', '_captain', '_charles', '_colnett', '_cook', '_cooper', '_cowper', '_cruise', '_currents', '_darwin', '_dryden', '_eckermann', '_edmund', '_elizabeth', '_falconer', '_frederick', '_from', '_fuller', '_gam_', '_genesis', '_goldsmith', '_grand', '_hackluyt', '_hamlet', '_hands', '_hawthorne', '_he', '_here_', '_history', '_ho', '_holland', '_ibid', '_isaiah', '_j', '_job', '_john', '_jonah', '_king', '_lay', '_life', '_lord', '_mcculloch', '_miriam', '_missionary', '_montgomery', '_my', '_n', '_nantucket', '_narrative', '_newspaper', '_obed', '_opening', '_other', '_paley', '_paradise', '_pilgrim', '_psalms', '_rabelais', '_rape', '_report', '_richard', '_richardson', '_schouten', '_scoresby', '_shoals', '_sibbald', '_sings', '_sir', '_something_', '_stowe', '_tales', '_thar', '_that', '_the', '_there', '_thomas', '_tooke', '_ulloa', '_uno', '_waller', '_webster', '_whale',
# ...

# %%
print(len(third))
# Out:
# 3636

# %%
third = []

for word in df:
    if df.at[0, word] > df.at[1, word] and word not in stopwords.words('english') and not word.isnumeric() and word[0] != "_":
        third.append(word)

# %%
print(third)
# Out:
# ['15th', '1_st', '200th', '21st', '275th', '2nd', '31_st', '3_d', 'aback', 'abaft', 'abandoned', 'abandonedly', 'abandonment', 'abased', 'abasement', 'abashed', 'abated', 'abating', 'abbreviate', 'abeam', 'abed', 'abednego', 'abel', 'abhorred', 'abhorrent', 'abhorring', 'abided', 'abiding', 'abjectly', 'abjectus', 'ablutions', 'aboard', 'abominable', 'abominate', 'abominated', 'abomination', 'aboriginal', 'aboriginally', 'aboriginalness', 'abortion', 'abortions', 'abound', 'abounded', 'aboundingly', 'abraham', 'abreast', 'abridged', 'abroad', 'abruptly', 'absent', 'absorbed', 'absorbing', 'absorbingly', 'abstained', 'abstemious', 'absurdly', 'accelerate', 'accelerated', 'accelerating', 'accepting', 'access', 'accessed', 'accessible', 'accident', 'accidentally', 'accidents', 'accommodate', 'accommodated', 'accompaniments', 'accompanying', 'accomplished', 'accomplishing', 'accordingly', 'accosted', 'accountants', 'accounted', 'accounting', 'accounts', 'accumulated', 'accumulating', 'ac
# ...

# %%
print(len(third))
# Out:
# 12296

# %%
f = open("moby-dick_tfidf_results.txt", "w")

f.write(", ".join(third))

f.close()
